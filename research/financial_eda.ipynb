# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from datetime import datetime, timedelta
import logging
import sys
import os

project_root = os.path.dirname(os.getcwd())
sys.path.append(project_root)

from data.config.database import *
from research.metrics import *
from research.utils import *
import seaborn as sns
import alphalens as al
from data.sql.financial_statements_snapshot import *
from data.sql.financial_indicators_snapshot import *
from data.sql.mv_monthly import *

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

# 配置日志
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# %%
calc=FinancialIndicatorsSnapshotCalculator()
# Out:
# 2026-01-14 16:21:18,991 - FinancialIndicatorsSnapshotCalculator - INFO - FinancialIndicatorsSnapshotCalculator 初始化完成，使用引擎: mysql+pymysql://root:Wmt9dbsj!@localhost:3306/stock?charset=utf8mb4
# 2026-01-14 16:21:18,991 - INFO - FinancialIndicatorsSnapshotCalculator 初始化完成，使用引擎: mysql+pymysql://root:Wmt9dbsj!@localhost:3306/stock?charset=utf8mb4
# 2026-01-14 16:21:18,998 - FinancialIndicatorsSnapshotCalculator - INFO - FinancialIndicatorsSnapshotCalculator 初始化完成
# 2026-01-14 16:21:18,998 - INFO - FinancialIndicatorsSnapshotCalculator 初始化完成

# %%
data=calc.incremental_update(snapshot_date='20251231',auto_save=False)
# Out:
# 2026-01-14 16:21:19,022 - FinancialIndicatorsSnapshotCalculator - INFO - 财务数据增量更新: 20251231
# 2026-01-14 16:21:19,022 - INFO - 财务数据增量更新: 20251231
# 2026-01-14 16:21:19,026 - FinancialIndicatorsSnapshotCalculator - INFO - 获取财务指标数据: 20251231, 股票数: 全部
# 2026-01-14 16:21:19,026 - INFO - 获取财务指标数据: 20251231, 股票数: 全部
# 2026-01-14 16:22:20,716 - FinancialIndicatorsSnapshotCalculator - INFO - 计算当季值，共13个
# 2026-01-14 16:22:20,716 - INFO - 计算当季值，共13个
# 2026-01-14 16:22:20,815 - FinancialIndicatorsSnapshotCalculator - INFO - 计算TTM值，共13个
# 2026-01-14 16:22:20,815 - INFO - 计算TTM值，共13个
# 2026-01-14 16:22:32,445 - FinancialIndicatorsSnapshotCalculator - INFO - 计算年度均值，共7个
# 2026-01-14 16:22:32,445 - INFO - 计算年度均值，共7个
# 2026-01-14 16:22:37,685 - FinancialIndicatorsSnapshotCalculator - INFO - 计算X/Y型指标，共85个
# 2026-01-14 16:22:37,685 - INFO - 计算X/Y型指标，共85个
# 2026-01-14 16:22:37,939 - FinancialIndicatorsSnapshotCalculator - INFO - 计算YOY指标，共57个
# 2026-01-14 16:22:37,939 - INFO - 计算YOY指标，共57个

# %%
calc.save_to_database(data,write_mode='append')
# Out:
# 2026-01-14 16:25:58,560 - INFO - 数据保存成功: financial_indicators_snapshot (88377 行, 模式: append)
# 2026-01-14 16:25:58,562 - FinancialIndicatorsSnapshotCalculator - INFO - 数据已保存到 financial_indicators_snapshot，共 88377 条记录，写入模式: append
# 2026-01-14 16:25:58,562 - INFO - 数据已保存到 financial_indicators_snapshot，共 88377 条记录，写入模式: append

# %%
raw_data=pd.read_sql_query("""select * from financial_statements_snapshot where snapshot_date='20251231'""", engine)

# %%
raw_data[raw_data.ts_code=='600710.SH'].tail(2)[['total_cur_liab','total_liab']]
# Out:
#        total_cur_liab    total_liab
# 53829    4.006373e+06  4.236634e+06
# 53830    4.140951e+06  4.437511e+06
